# %%
import numpy as np
from tensorflow.keras import datasets

# %%
(X_train,y_train),(X_test,y_test)=datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 43s 0us/step

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_train=X_train/255
X_test=X_test/255

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense,Conv2D,MaxPooling2D

# %%
model=Sequential([
    Conv2D(filters=32,kernel_size=(3,3),activation='relu',input_shape=(32, 32, 3)),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=64,kernel_size=(2,2),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(100,activation='relu'),
    Dense(10,activation='softmax')
    
])
# Out:
# WARNING:tensorflow:From C:\Users\murali\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\murali\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 38s 23ms/step - loss: 1.4601 - accuracy: 0.4750
# Epoch 2/10
# 1563/1563 [==============================] - 34s 22ms/step - loss: 1.1046 - accuracy: 0.6121
# Epoch 3/10
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.9767 - accuracy: 0.6591
# Epoch 4/10
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.8906 - accuracy: 0.6905
# Epoch 5/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.8203 - accuracy: 0.7133
# Epoch 6/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.7621 - accuracy: 0.7319
# Epoch 7/10
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.7063 - accuracy: 0.7535
# Epoch 8/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.6520 - accuracy: 0.7703
# Epoch 9/10
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.6075 - accuracy: 0.7863
# Epoch 10/10
# 1563/1563 [==============================] - 34s 22ms/step - loss: 0.5624 - accuracy: 0.8028

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.9206 - accuracy: 0.7019
# [0.9205868244171143, 0.7019000053405762]

# %%
y_pred=model.predict(X_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step

# %%
classes=[np.argmax(x) for x in y_pred]

# %%
classes[:5]
# Out:
# [8, 8, 8, 0, 4]

# %%
plt.figure(figsize=(15,2))
plt.matshow(X_test[0])

# %%
import matplotlib.pyplot as plt

for i in range(0,5):
    plt.figure(figsize=(1, 1))
    plt.imshow(X_test[i])
    plt.show()

# %%
classes[:5]
# Out:
# [8, 8, 8, 0, 4]
